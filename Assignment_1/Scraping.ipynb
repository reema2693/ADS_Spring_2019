# %%
import requests
from bs4 import BeautifulSoup, Comment
import pandas as pd
import re
import matplotlib.pyplot as plt

url='https://statestreet.wd1.myworkdayjobs.com/Global'
content = requests.get(url).text

#initalizing an empty dictionary that would be written as Pandas Dataframe and then CSV
d = {'title':[],'links':[],'class':[]}

#initializing blog hosting category
#cat = {'blogspot':0,'wordpress':0,'others':0}
soup = BeautifulSoup(content, "html.parser")
#print(soup)
for link in soup.find_all('floatingCirclesG',):
    if len(link.text.strip()) > 1 and bool(re.match('^http',link['href'])) and not bool(re.search('bbt.wd1.myworkdayjobs.com',link['href'])):
        d['title'].append(link.text)
        d['links'].append(link['href'])

list1 = pd.DataFrame(d).set_index('title')
#print (list.head())
list1.to_csv('/Users/rajsharavan/Desktop/Python/list111.csv', encoding='utf-8')
print(str(len(list1.index))+' rows written')
# Out:
# 0 rows written

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

url = 'https://bbt.wd1.myworkdayjobs.com/Careers'
res = requests.get(url)

soup = BeautifulSoup(res.content, 'lxml')
for link in soup.select('[itemprop=title]'):
    absolute_link = urljoin(url,link.get('href'))
    print(absolute_link)
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
#
#   <head>
#     <!-- Application Properties -->
#     <meta http-equiv="X-UA-Compatible" content="chrome=1;IE=EDGE" />
#     <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0">
#
#
# 	<title>Workday</title>
# 	<link rel="icon" href="/assets/images/favicon.ico">
#
#     <!-- Stylesheets -->
#     <style type="text/css" rel="stylesheet">
#
#
#
#     body#vpsBody div#workdayApplicationHeader,
#     body#vpsBody div#workdayApplicationFrame {
#         margin: 0px auto 0px auto;
#         max-width: 1098px;
#         border-left: 1px solid #e5e5e5;
#         border-right: 1px solid #e5e5e5;
#         background-color: #f7f7f7;
#     }
#
#
# div[automationid='toolbarButtonContainer'] {
#     margin: auto;
#     max-width: 1060px;
# }
#
# #wd-FacetedSearchResult-facetSearchResult > div > span.gwt-InlineLabel {
#     display: none;
# }
#
# ...

# %%
import PyPDF2 
  
def PDFsplit(pdf, splits): 
    # creating input pdf file object 
    pdfFileObj = open(pdf, 'rb') 
      
    # creating pdf reader object 
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj) 
      
    # starting index of first slice 
    start = 0
      
    # starting index of last slice 
    end = splits[0] 
      
    for i in range(len(splits)+1): 
        # creating pdf writer object for (i+1)th split 
        pdfWriter = PyPDF2.PdfFileWriter() 
          
        # output pdf file name 
        outputpdf = pdf.split('.pdf')[0] + str(i) + '.pdf'
        #print(outputpdf)
          
        # adding pages to pdf writer object 
        for page in range(start,end): 
            pdfWriter.addPage(pdfReader.getPage(page)) 
          
        # writing split pdf pages to pdf file 
        with open(outputpdf, "wb") as f: 
            pdfWriter.write(f) 
  
        # interchanging page split start position for next split 
        start = end 
        print(end)
        try: 
            # setting split end positon for next split 
            end = splits[i+1 ]
        except IndexError: 
            # setting split end position for last split 
            end = pdfReader.numPages 
          
    # closing the input pdf file object 
    pdfFileObj.close() 
              
def main(): 
    # pdf file to split 
    pdf = '/Users/rajsharavan/Desktop/Python/Sample3.pdf'
      
    # split page positions 
    splits = [30,3] 
      
    # calling PDFsplit function to split pdf 
    PDFsplit(pdf, splits) 
if __name__ == "__main__": 
    # calling the main function 
    main()
# Out:
# 30
# 31
# 31
# 4
# 4

# %%
from PyPDF2 import PdfFileWriter, PdfFileReader

inputpdf = PdfFileReader(open('/Users/rajsharavan/Desktop/Python/Sample3.pdf', 'rb'))
print(range(inputpdf.numPages))
for i in range(inputpdf.numPages):
    output = PdfFileWriter()
    output.addPage(inputpdf.getPage(i))
# Out:
# range(0, 108)

# %%
with open("document-page%s.pdf" % i, "wb") as outputStream:
        output.write(outputStream)

# %%
import PyPDF2 
  
def PDFsplit(pdf, splits): 
    # creating input pdf file object 
    pdfFileObj = open(pdf, 'rb') 
      
    # creating pdf reader object 
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj) 
      
    # starting index of first slice 
    start = 0
      
    # starting index of last slice 
    end = splits[0] 

    for i in range(len(splits)+2): 
#        print(len(splits)+2)
        # creating pdf writer object for (i+1)th split 
        pdfWriter = PyPDF2.PdfFileWriter() 
#        print(str(i))
        # output pdf file name 
        outputpdf = pdf.split('.pdf')[0] + str(i) + '.pdf'
#        print(range(start,end))
        # adding pages to pdf writer object 
        for page in range(start,end): 
            pdfWriter.addPage(pdfReader.getPage(page)) 
          
        # writing split pdf pages to pdf file 
        with open(outputpdf, "wb") as f: 
            pdfWriter.write(f) 
  
        # interchanging page split start position for next split 
        start = end 
        try: 
            # setting split end positon for next split 
            end = splits[i+1] 
        except IndexError: 
            # setting split end position for last split 
            end = pdfReader.numPages 
          
    # closing the input pdf file object 
    pdfFileObj.close() 
              
def main(): 
    # pdf file to split 
    pdf = '/Users/rajsharavan/Desktop/Python/Splitted PDF/Sample4.pdf'
      
    # split page positions 
    splits = [40,80,120,160]
      
    # calling PDFsplit function to split pdf 
    PDFsplit(pdf, splits) 
    
if __name__ == "__main__": 
    # calling the main function 
    main()

# %%
import requests
from bs4 import BeautifulSoup, Comment
import pandas as pd
import re
import matplotlib.pyplot as plt

url='https://bbt.wd1.myworkdayjobs.com/Careers'
content = requests.get(url).text

#initalizing an empty dictionary that would be written as Pandas Dataframe and then CSV
d = {'title':[],'links':[],'class':[]}

#initializing blog hosting category
#cat = {'blogspot':0,'wordpress':0,'others':0}
soup = BeautifulSoup(content, "html.parser")
#print(soup)
movie_containers = soup.find_all('div', class_ = 'floatingCirclesG')
#print(movie_containers)
abcd = movie_containers[0]
print(abcd)
# Out:
# <div class="floatingCirclesG" id="spinnerContainer">
# <div class="f_circleG followingBalls1"></div>
# <div class="f_circleG followingBalls2"></div>
# <div class="f_circleG followingBalls3"></div>
# <div class="f_circleG followingBalls4"></div>
# <div class="f_circleG followingBalls5"></div>
# <div class="f_circleG followingBalls6"></div>
# <div class="f_circleG followingBalls7"></div>
# <div class="f_circleG followingBalls8"></div>
# </div>

# %%
abcd.div
# Out:
# <div class="f_circleG followingBalls1"></div>

# %%
from bs4 import BeautifulSoup
import urllib.request
import csv

# %%
urlpage =  'https://bbt.wd1.myworkdayjobs.com/Careers'

# %%
# query the website and return the html to the variable 'page'
page = urllib.request.urlopen(urlpage)
# parse the html using beautiful soup and store in variable 'soup'
soup = BeautifulSoup(page, 'html.parser')

# %%
#print(soup)

# %%
# find results within table
table = soup.find_all('div', attrs={'class': 'WJ2N WN1N'})

# %%
print(table)
# Out:
# []

# %%
from selenium import webdriver
import pandas as pd

# %%
driver = webdriver.Chrome()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/common/service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# ~/anaconda3/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     768                                 errread, errwrite,
# --> 769                                 restore_signals, start_new_session)
#     770         except:
#
# ...

# %%
import time
from selenium import webdriver

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://statestreet.wd1.myworkdayjobs.com/Global');
time.sleep(5) # Let the user actually see something!
search_box = driver.find_element_by_class_name('WMWQ WOVQ WFXQ')
print(search_box)
search_box.send_keys('ChromeDriver')
search_box.submit()
time.sleep(5) # Let the user actually see something!
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# <ipython-input-7-e73d54d31dea> in <module>
#       5 driver.get('https://statestreet.wd1.myworkdayjobs.com/Global');
#       6 time.sleep(5) # Let the user actually see something!
# ----> 7 search_box = driver.find_element_by_class_name('WMWQ WOVQ WFXQ')
#       8 print(search_box)
#       9 search_box.send_keys('ChromeDriver')
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
# ...

# %%
import time
from selenium import webdriver
import workday

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://statestreet.wd1.myworkdayjobs.com/Global');
time.sleep(5) # Let the user actually see something!
python_button = driver.find_element_by_id('wd-FacetedSearchResultList-facetSearchResultList.newFacetSearch.Report_Entry')
python_button.click() #click fhsu link

ids = driver.find_elements_by_xpath("//*[contains(@id,'maincontent')]")
comment_ids = []
for i in ids:
    comment_ids.append(i.get_attribute('id'))

# %%
comment_ids
print(python_button)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="7b025e2cf00d2360ff2f6f331e99bc62", element="0.4671106250950452-1")>

# %%
import requests
from bs4 import BeautifulSoup, Comment
import pandas as pd
import re
import matplotlib.pyplot as plt

url='https://bbt.wd1.myworkdayjobs.com/Careers'
content = requests.get(url).text

#initalizing an empty dictionary that would be written as Pandas Dataframe and then CSV
d = {'title':[],'links':[],'class':[]}

#initializing blog hosting category
#cat = {'blogspot':0,'wordpress':0,'others':0}
soup = BeautifulSoup(content, "html.parser")
#print(soup)
for link in soup.find_all('a',):
    if len(link.text.strip()) > 1 and bool(re.match('^http',link['href'])) and not bool(re.search('bbt.wd1.myworkdayjobs.com',link['href'])):
        d['title'].append(link.text)
        d['links'].append(link['href'])

list1 = pd.DataFrame(d).set_index('title')
#print (list.head())
list1.to_csv('/Users/rajsharavan/Desktop/Python/list111.csv', encoding='utf-8')
print(str(len(list1.index))+' rows written')
# Out:
# 0 rows written

# %%
from urllib.request import urlopen 
from bs4 import BeautifulSoup 
html = urlopen('https://bbt.wd1.myworkdayjobs.com/Careers') 
res = BeautifulSoup(html.read(),"html5lib"); 
print(res.iframe)
# Out:
# <iframe id="__gwt_historyFrame" src="javascript:''" tabindex="-1"></iframe>

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://bbt.wd1.myworkdayjobs.com/Careers'
r = requests.get(url)
html_soup = BeautifulSoup(r.text, 'html.parser')
# No tag will be found here ul_tag = html_soup.find('ul') print(ul_tag)
ul_tag = html_soup.find('ul') 
print(ul_tag)
# Show the JavaScript code
script_tag = html_soup.find('script', attrs={'src': None})
print(script_tag)
# Out:
# None
# <script type="text/javascript">
#               var storeAnchorCookie = false;
#               document.cookie = "timezoneOffset =" + new Date().getTimezoneOffset() +"; path=/;secure";
#
#               function renderWorkdayApp() {
#                   workday.clientRenderer.renderWorkdayApp({
#                       baseDir: "/wday/uiclient/static/gwt-desktop/",
#                       cdn: {
#                           endpoint: 'www.myworkdaycdn.com',
#                           enabled: true,
#                           allowed: true
#                       },
#                       systemConfidenceLevel: "PROD",
#                       proxyEnabled: false,
#                       currentVersion: "22",
#                       serviceType: "",
#                       loginAuthURL: "",
#                       environment: "stuff",
#                       environmentType: "stuff",
#                       newUxDisabled: false
#                   });
#
#
# ...

# %%
import time
import re
from selenium import webdriver
import csv
from bs4 import BeautifulSoup as bs
import requests
# specify the url

page = requests.get('https://bbt.wd1.myworkdayjobs.com/en-US/Careers/job/Charlotte-NC/Security-Intelligence-and-Reponse-Coordinator_R0013214')
# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')
#print(soup)

browser = webdriver.Chrome()

# Tell Selenium to get the URL you're interested in.
browser.get("https://bbt.wd1.myworkdayjobs.com/en-US/Careers/job/Charlotte-NC/Security-Intelligence-and-Reponse-Coordinator_R0013214")

# Now that the page is fully scrolled, grab the source code.
source_data = browser.page_source

# Throw your source into BeautifulSoup and start parsing!
bs_data = bs(source_data, "lxml")
#print(bs_data)

test_links = bs_data.find_all('div',attrs={'class':'WIRP WGQP WE5'})
print(test_links)
browser.close()
# Out:
# []

# %%
from lxml import html
import requests
page = requests.get('https://bbt.wd1.myworkdayjobs.com/en-US/Careers/job/Charlotte-NC/Security-Intelligence-and-Reponse-Coordinator_R0013214')
tree = html.fromstring(page.content)
#This will create a list of buyers:
buyers = tree.xpath('//div[@class="GWTCKEditor-Disabled"]/text()')
#This will create a list of prices
#prices = tree.xpath('//span[@class="item-price"]/text()')

print(buyers)
#print 'Prices: ', prices
# Out:
# []

# %%
import time
import re
from selenium import webdriver
from bs4 import BeautifulSoup as bs
from selenium.webdriver import ActionChains
from selenium.webdriver.common.keys import Keys

browser = webdriver.Chrome()

# Tell Selenium to get the URL you're interested in.
browser.get("https://statestreet.wd1.myworkdayjobs.com/Global")
# browser.implicitly_wait(100)

# Selenium script to scroll to the bottom, wait 3 seconds for the next batch of data to load, then continue scrolling.  It will continue to do this until the page stops loading new data.
lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
match=False
while(match==False):
    lastCount = lenOfPage
    time.sleep(3)
    lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
    if lastCount==lenOfPage:
        print('lastCount and lenOfPage matched: ',lenOfPage)
        match=True

# title = browser.find_element_by_xpath('//*[@id="monikerList"]')
# title = browser.find_element_by_class_name('gwt-Label WOTO WISO')
# print(title)

# //*[@id="promptOption-gwt-uid-207"]
# # Now that the page is fully scrolled, grab the source code.
source_data = browser.page_source

# Throw your source into BeautifulSoup and start parsing!
bs_data = bs(source_data, "lxml")

# print(bs_data)

base_url = 'https://statestreet.wd1.myworkdayjobs.com/en-US/Global/job/'
test_links = bs_data.find_all('li',attrs={'class':'WIYF WK3N WE5 WP-F'})
# # my_str = "hey th~!ere"
# # my_new_string = re.sub('[^a-zA-Z0-9 \n\.]', '', my_str)
# # print my_new_string

# for link in test_links:
# title = browser.find_element_by_class_name('gwt-Label WOTO WISO').text
# titles = browser.find_elements_by_class_name('gwt-Label WOTO WISO')
title = browser.find_element_by_xpath('//*[@id="promptOption-gwt-uid-1"]')
sub_menu = browser.find_element_by_class_name('gwt-Label')
actionChains = ActionChains(browser)
right_click = actionChains.context_click(title).perform()
ActionChains.send_keys(Keys.ARROW_DOWN).send_keys(Keys.ARROW_DOWN).send_keys(Keys.ENTER).build().perform()
#right_click.send_keys(Keys.ARROW_DOWN).send_keys(Keys.ARROW_DOWN).send_keys(Keys.ENTER).build().perform()
# Out:
# lastCount and lenOfPage matched:  26974
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-ab41d701f5e8> in <module>
#      49 actionChains = ActionChains(browser)
#      50 right_click = actionChains.context_click(title).perform()
# ---> 51 ActionChains.send_keys(Keys.ARROW_DOWN).send_keys(Keys.ARROW_DOWN).send_keys(Keys.ENTER).build().perform()
#      52 #right_click.send_keys(Keys.ARROW_DOWN).send_keys(Keys.ARROW_DOWN).send_keys(Keys.ENTER).build().perform()
#      53
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/common/action_chains.py in send_keys(self, *keys_to_send)
#     334         """
#     335         typing = keys_to_typing(keys_to_send)
# --> 336         if self._driver.w3c:
#     337             for key in typing:
#     338                 self.key_down(key)
#
# AttributeError: 'str' object has no attribute '_driver'
