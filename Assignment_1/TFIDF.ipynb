# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize,sent_tokenize
import collections
from tika import parser
import csv
import re
import math

parsedPDF1 = parser.from_file(r'/Users/rajsharavan/Desktop/Python/sample1.pdf')
pdf1 = parsedPDF1['content']
parsedPDF2 = parser.from_file(r'/Users/rajsharavan/Desktop/Python/sample2.pdf')
pdf2 = parsedPDF2['content']
parsedPDF3 = parser.from_file(r'/Users/rajsharavan/Desktop/Python/sample3.pdf')
pdf3 = parsedPDF3['content']
parsedPDF4 = parser.from_file(r'/Users/rajsharavan/Desktop/Python/sample4.pdf')
pdf4 = parsedPDF4['content']


#TF/IDF
def remove_string_special_chars(s):
    #Replace special character with " "
    stripped = re.sub('[^\w\s]','',s)
    stripped = re.sub('_','',stripped)
    
    #Change any whitespace to one space
    stripped = re.sub('\s+',' ',stripped)
    
    #Remove start and end white spaces
    stripped = stripped.strip()
    
    return stripped

def get_doc(sent):
    doc_info = []
    i=0
    for sent in text_sents_clean:
        i+=1
        count=count_word(sent)
        temp = {'doc_id':i, 'doc_length':count}
        doc_info.append(temp)
    return doc_info


def count_word(sent):
    count=0
    words = word_tokenize(sent)
    for word in words:
        count += 1
    return count


def create_freq_dict(sents):
    i =0
    freqDict_list=[]
    for sent in sents:
        i+=1
        freq_dict = {}
        words = word_tokenize(sent)
        for word in words:
            word = word.lower()
            if word in freq_dict:
                freq_dict[word]+=1
            else:
                freq_dict[word]=1
            temp ={'doc_id':i,'freq_dict':freq_dict}
        freqDict_list.append(temp)
    return freqDict_list

def computeTF(doc_info,freqDict_list):
    #tf = (frequency of the term in the doc)/(total number of terms in doc)
    TF_scores = []
    for tempDict in freqDict_list:
        id = tempDict['doc_id']
        for k in tempDict['freq_dict']:
            temp = {'doc_id':id,
                   'TF_score': tempDict['freq_dict'][k]/doc_info[id-1]['doc_length'],'key':k}
            TF_scores.append(temp)
    return TF_scores

def computeIDF(doc_info,freqDict_list):
    #idf = ln(total number of docs/number of docs with term in it)
    IDF_scores = []
    counter = 0
    for dict in freqDict_list:
        counter+=1
        for k in dict['freq_dict'].keys():
            count = sum([k in tempDict['freq_dict'] for tempDict in freqDict_list])
            temp = {'doc_id': counter,'IDF_score': math.log(len(doc_info)/count), 'key':k}
            
            IDF_scores.append(temp)
            
    return IDF_scores

def computeTFIDF(TF_scores,IDF_scores):
    TFIDF_scores = []
    for j in IDF_scores:
        for i in TF_scores:
            if j['key']== i['key'] and j['doc_id'] == i['doc_id']:
                temp={'doc_id':j['doc_id'],'key': i['key'],'TFIDF_score':j['IDF_score']*i['TF_score']}
            TFIDF_scores.append(temp)
    return TFIDF_scores

#Executing Functions
                    
text_sents = sent_tokenize(pdf1)
#print(text_sents)

text_sents_clean = [remove_string_special_chars(s) for s in text_sents]
#print(text_sents_clean)

doc_info = get_doc(text_sents_clean)
# Counting total number of words in the text
# countwords = count_word(text_sents_clean)
# print()

freqDict_List = create_freq_dict(text_sents_clean)
#print(freqDist_List)

# get_doc = get_doc(pdf1)
# print(get_doc)
TF_scores = computeTF(doc_info,freqDict_List)
IDF_scores = computeIDF(doc_info,freqDict_List)

#print("IDF_scores")
#print(IDF_scores)
#print("TF_scores")
#print(TF_scores)

TFIDF_scores = computeTFIDF(TF_scores, IDF_scores)
# #TFIDF_scores
print(hello)
print("TFIDF_scores")
print(TFIDF_scores)

# %%
import sys
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.converter import XMLConverter, HTMLConverter, TextConverter
from pdfminer.layout import LAParams
import io
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
import collections
from tika import parser
import csv

def pdfparser(data):

    fp = open(data, 'rb')
    rsrcmgr = PDFResourceManager()
    retstr = io.StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    # Create a PDF interpreter object.
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    # Process each page contained in the document.
    stop_words100 = set(stopwords.words('english')) 
    for page in PDFPage.get_pages(fp):
        interpreter.process_page(page)
        data =  retstr.getvalue()
    #print(data)
    print(type(data))
    word_tokens100 = word_tokenize(data)
    words100 = [w1 for w1 in word_tokens100 if w1.isalpha()]
    filtered_sentence100 = []  
    for w1 in words100: 
        #w.lower()
        #print(w.lower())
        if w1.lower() not in stop_words100: 
            filtered_sentence100.append(w1)
    print(len(filtered_sentence100))
    #print(filtered_sentence100)
    
    def get_count(word_count_tuple):
        return word_count_tuple[1]

    word_counts = collections.Counter(filtered_sentence100)

# It sorts the words based on the number of times repeated and saves them in a csv file
    def print_top():
        word_count = word_counts
        items = sorted(word_count.items(),key=get_count,reverse=True)
        with open('/Users/rajsharavan/Desktop/Python/WordList1.csv','w') as out:
            csv_out=csv.writer(out)
            #        csv_out.writerow('Name')
            for row in items:
                csv_out.writerow(row)
#    for item in items[:]:
#        (item[0],item[1])
#        print(type(item))
#        print(item[0],item[1])
#        print (item[0], 'has been repeated ', item[1],' times')
#print(type(item))

    print_top()

# %%
path = ('/Users/rajsharavan/Desktop/Python/sample1.pdf')
pdfparser(path)
# Out:
# <class 'str'>
# 15609

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize,sent_tokenize
import collections
from tika import parser
import csv
import re
import math

parsedPDF1 = parser.from_file(r'/Users/rajsharavan/Desktop/Python/sample1.pdf')
pdf1 = parsedPDF1['content']
parsedPDF2 = parser.from_file(r'/Users/rajsharavan/Desktop/Python/sample2.pdf')
pdf2 = parsedPDF2['content']
parsedPDF3 = parser.from_file(r'/Users/rajsharavan/Desktop/Python/sample3.pdf')
pdf3 = parsedPDF3['content']
parsedPDF4 = parser.from_file(r'/Users/rajsharavan/Desktop/Python/sample4.pdf')
pdf4 = parsedPDF4['content']


#TF/IDF
def remove_string_special_chars(s):
    #Replace special character with " "
    stripped = re.sub('[^\w\s]','',s)
    stripped = re.sub('_','',stripped)
    
    #Change any whitespace to one space
    stripped = re.sub('\s+',' ',stripped)
    
    #Remove start and end white spaces
    stripped = stripped.strip()
    
    return stripped

def get_doc(sent):
    doc_info = []
    i=0
    for sent in text_sents_clean:
        i+=1
        count=count_word(sent)
        temp = {'doc_id':i, 'doc_length':count}
        doc_info.append(temp)
    return doc_info


def count_word(sent):
    count=0
    words = word_tokenize(sent)
    for word in words:
        count += 1
    return count


def create_freq_dict(sents):
    i =0
    freqDict_list=[]
    for sent in sents:
        i+=1
        freq_dict = {}
        words = word_tokenize(sent)
        for word in words:
            word = word.lower()
            if word in freq_dict:
                freq_dict[word]+=1
            else:
                freq_dict[word]=1
            temp ={'doc_id':i,'freq_dict':freq_dict}
        freqDict_list.append(temp)
    return freqDict_list

def computeTF(doc_info,freqDict_list):
    #tf = (frequency of the term in the doc)/(total number of terms in doc)
    TF_scores = []
    for tempDict in freqDict_list:
        id = tempDict['doc_id']
        for k in tempDict['freq_dict']:
            temp = {'doc_id':id,
                   'TF_score': tempDict['freq_dict'][k]/doc_info[id-1]['doc_length'],'key':k}
            TF_scores.append(temp)
    return TF_scores

def computeIDF(doc_info,freqDict_list):
    #idf = ln(total number of docs/number of docs with term in it)
    IDF_scores = []
    counter = 0
    for dict in freqDict_list:
        counter+=1
        for k in dict['freq_dict'].keys():
            count = sum([k in tempDict['freq_dict'] for tempDict in freqDict_list])
            temp = {'doc_id': counter,'IDF_score': math.log(len(doc_info)/count), 'key':k}
            
            IDF_scores.append(temp)
            
    return IDF_scores

def computeTFIDF(TF_scores,IDF_scores):
    TFIDF_scores = []
    for j in IDF_scores:
        for i in TF_scores:
            if j['key']== i['key'] and j['doc_id'] == i['doc_id']:
                temp={'doc_id':j['doc_id'],'key': i['key'],'TFIDF_score':j['IDF_score']*i['TF_score']}
            TFIDF_scores.append(temp)
    return TFIDF_scores

#Executing Functions
                    
text_sents = sent_tokenize(pdf1)
#print(text_sents)

text_sents_clean = [remove_string_special_chars(s) for s in text_sents]
#print(text_sents_clean)

doc_info = get_doc(text_sents_clean)
# Counting total number of words in the text
# countwords = count_word(text_sents_clean)
# print()

freqDict_List = create_freq_dict(text_sents_clean)
#print(freqDist_List)

# get_doc = get_doc(pdf1)
# print(get_doc)
TF_scores = computeTF(doc_info,freqDict_List)
IDF_scores = computeIDF(doc_info,freqDict_List)

#print("IDF_scores")
#print(IDF_scores)
#print("TF_scores")
#print(TF_scores)

TFIDF_scores = computeTFIDF(TF_scores, IDF_scores)
# #TFIDF_scores
print(hello)
print("TFIDF_scores")
print(TFIDF_scores)
# Out:
# 2019-02-04 17:53:11,560 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server/1.19/tika-server-1.19.jar to /var/folders/w4/4sg55yq56ln4zzs5jb0j7xjr0000gn/T/tika-server.jar.
# 2019-02-04 17:53:46,095 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server/1.19/tika-server-1.19.jar.md5 to /var/folders/w4/4sg55yq56ln4zzs5jb0j7xjr0000gn/T/tika-server.jar.md5.
# 2019-02-04 17:53:46,361 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# ...
