# %%
#this is a crawler, need to find out the logic of including this with python code
function pageFunction(context) {
    // called on every page the crawler visits, use it to extract data from it
    var $ = context.jQuery;
    if (context.request.label === 'start') {
        context.skipOutput();
        var count = parseInt($('.count').text());
        for(var i=0; i<=count; i+=20) {
            context.enqueuePage("http://www.topshop.com/webapp/wcs/stores/servlet/CatalogNavigationAjaxSearchResultCmd?storeId=12556&catalogId=33057&langId=-1&dimSelected=%2Fen%2Ftsuk%2Fcategory%2Fclothing-427%2FN-82zZdgl%3FNo%3D" + i + "%26Nrpp%3D20%26siteId%3D%252F12556%26categoryId%3D203984");
        }
    } else {
        var jsonObject = JSON.parse($('body pre').text());
        return jsonObject.results.contents[0].records;
    }
}
# Out:
#   File "<ipython-input-1-8d954ea2aa4a>", line 1
#     function pageFunction(context) {
#                         ^
# SyntaxError: invalid syntax

# %%
import time
from selenium import webdriver
from bs4 import BeautifulSoup as bs

browser = webdriver.Chrome()

# Tell Selenium to get the URL you're interested in.
browser.get("https://statestreet.wd1.myworkdayjobs.com/Global")
# browser.implicitly_wait(100)

# Selenium script to scroll to the bottom, wait 3 seconds for the next batch of data to load, then continue scrolling.  It will continue to do this until the page stops loading new data.
lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
#print('Initial page length: ',lenOfPage)
match=False
while(match==False):
    lastCount = lenOfPage
    time.sleep(3)
    lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
#    print('lenOfPage in while loop: ',lenOfPage)
    if lastCount==lenOfPage:
#        print('lastCount and lenOfPage matched: ',lenOfPage)
        match=True

# Now that the page is fully scrolled, grab the source code.
source_data = browser.page_source

# Throw your source into BeautifulSoup and start parsing!
bs_data = bs(source_data, "lxml")

#print(bs_data)
# working for retreiving all the job names
job_descrp = bs_data.find_all('div',attrs={'class':'gwt-Label WOTO WISO'})

for job in job_descrp:
    job.get_text()
#    print(job.get_text())

# working for retrieving all the locations
label = bs_data.find_all('span', attrs ={'class':'gwt-InlineLabel WM-F WLYF'})

for lblname in label:
    lblname.get_text()
#    print(lblname.get_text())
    
    
div_span_text = bs_data.find_all('li',attrs={'class':'WIYF WK3N WE5 WP-F'})
for dvsp in div_span_text:
    print(dvsp.get_text())
# code_blocks = []

# code_blocks.append(job_names)

# print(code_blocks)
# Out:
# Initial page length:  0
# Fall 2019 Financial Reporting Graduate InternshipKansas City, Missouri   |   R-608399   |   Posted Today
# Fall 2019 Financial Services Undergraduate InternshipKansas City, Missouri   |   R-608398   |   Posted Today
# Central Assurance Manager - North America, VPBoston, Massachusetts   |   R-600641   |   Posted Today
# Senior Financial Analyst- Charles River DevelopmentBurlington Massachusetts   |   R-606838   |   Posted Today
# Senior Financial Analyst- Charles River DevelopmentBurlington Massachusetts   |   R-606845   |   Posted Today
# Finance Manager- Charles River DevelopmentBurlington Massachusetts   |   R-606839   |   Posted Today
# Business Production Support SpecialistGdansk, Poland   |   R-606661   |   Posted Today
# Platform Product Strategist; Vice President; Global Exchange/CRDBoston, Massachusetts   |   R-608389   |   Posted Today
# IFDS Transfer Agency, Client Relationsip Manager - Senior AssociateDublin 2, Ireland   |   R-599466   |   Posted Today
# Oracle Golden Gate DBABangalore, India   |   R-604366   |   Posted Today
# Senior Consultant - C#, Java, Middleware, RDBMS - Charles River DevelopmentDayton, Nevada   |   R-607251   |   Posted Today
# Fund Accounting,Associate2Hyderabad, India   |   R-607837   |   Posted Today
# Vice President, Global Human Resources (GHR) TechnologyBoston, Massachusetts   |   R-603828   |   Posted Today
# Fund Accounting,Associate 2Hyderabad, India   |   R-607258   |   Posted Today
# Transition ManagerBangalore, India   |   R-608378   |   Posted Today
# Fund Accounting,Associate 2Hyderabad, India   |   R-606509   |   Posted Today
# Financial Reporting Team Leader, Senior AssociateKrakow, Poland   |   R-606216   |   Posted Today
# Principal Java DeveloperBurlington Massachusetts   |   R-606946   |   Posted Today
# Sr. Java DeveloperBurlington Massachusetts   |   R-606888   |   Posted Today
# Financial Reporting Subject Matter Expert, Senior AssociateKrakow, Poland   |   R-606188   |   Posted Today
# Incident Management Analyst -Senior AssociateHyderabad, India   |   R-608351   |   Posted Today
# Incident Management Analyst-Senior AssociateHyderabad, India   |   R-608352   |   Posted Today
# Sr. ManagerBangalore, India   |   R-608145   |   Posted Today
# Manager - TreasuryBangalore, India   |   R-608333   |   Posted Today
# Financial Reporting Team Manager, OfficerKrakow, Poland   |   R-606645   |   Posted Today
# Associate 2 - TreasuryBangalore, India   |   R-608268   |   Posted Today
# Associate 2 - TreasuryBangalore, India   |   R-608264   |   Posted Today
# Associate 2 - TreasuryBangalore, India   |   R-608240   |   Posted Today
# Associate 2 - TreasuryBangalore, India   |   R-608238   |   Posted Today
# AML Senior Specialist,Sr AsscBangalore, India   |   R-607733   |   Posted Today
# Emerging Leader - FRFA TaxBangalore, India   |   R-607327   |   Posted Today
# Spring Internship - IFDS Luxembourg (6 Months)Luxembourg, Luxembourg   |   R-605832   |   Posted Today
# Network Engineer,  OfficerKrakow, Poland   |   R-604789   |   Posted Today
# Senior Transfer Agent-Client Service Management, Associate 2Luxembourg, Luxembourg   |   R-604902   |   Posted Today
# IFDS - Automated Workflow Distribution (AWD) European Product Manager - Assistant Vice PresidentDublin 2, Ireland   |   R-608312   |   Posted Today
# Outsourcing Oversight and Governance Support, AVPDublin 2, Ireland   |   R-608361   |   Posted Today
# SA- Asst Manager  - RFX Services-2Bangalore, India   |   R-607488   |   Posted Today
# Regional HR Business PartnerKrakow, Poland, More...   |   R-608357   |   Posted Today
# Financial Regulatory Reporting - Assistant Vice PresidentBangalore, India   |   R-579479   |   Posted Today
# Team Lead - Revenue OperationsBangalore, India   |   R-607235   |   Posted Today
# IFDS - Transfer Agent , Registration , German Speaker , Associate -1Luxembourg, Luxembourg   |   R-607897   |   Posted Today
# Senior Depositary Analyst, Associate 2Gdansk, Poland   |   R-605614   |   Posted Today
# Devops-Senior AssociateBangalore, India   |   R-608322   |   Posted Today
# AIS Middle Office Operations Specialist-Associate 1Bangalore, India   |   R-607950   |   Posted Today
# Treasury - Associate 2Bangalore, India   |   R-608274   |   Posted Today
# IFDS  Transfer Agent - Investor Service (German Speaker), Associate 1Luxembourg, Luxembourg   |   R-605734   |   Posted Today
# AIS Middle Office Operations Specialist-Associate 2Bangalore, India   |   R-607952   |   Posted Today
# Treasury - OfficerHyderabad, India   |   R-608277   |   Posted Today
# CLO - Team LeaderBangalore, India   |   R-608296   |   Posted Today
# Fund Accounting- Associate 2-3Hyderabad, India   |   R-607229   |   Posted Today

# %%
import time
import re
from selenium import webdriver
from bs4 import BeautifulSoup as bs

browser = webdriver.Chrome()

# Tell Selenium to get the URL you're interested in.
browser.get("https://statestreet.wd1.myworkdayjobs.com/Global")
# browser.implicitly_wait(100)

# Selenium script to scroll to the bottom, wait 3 seconds for the next batch of data to load, then continue scrolling.  It will continue to do this until the page stops loading new data.
lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
match=False
while(match==False):
    lastCount = lenOfPage
    time.sleep(3)
    lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
    if lastCount==lenOfPage:
        print('lastCount and lenOfPage matched: ',lenOfPage)
        match=True

# Now that the page is fully scrolled, grab the source code.
source_data = browser.page_source

# Throw your source into BeautifulSoup and start parsing!
bs_data = bs(source_data, "lxml")

#print(bs_data)

base_url = 'https://statestreet.wd1.myworkdayjobs.com/en-US/Global/job/'

test_links = bs_data.find_all('li',attrs={'class':'WIYF WK3N WE5 WP-F'})



# my_str = "hey th~!ere"
# my_new_string = re.sub('[^a-zA-Z0-9 \n\.]', '', my_str)
# print my_new_string

for link in test_links:
    designation = link.find('div',attrs={'class':'gwt-Label WOTO WISO'})
    address = link.find('span', attrs={'class':'gwt-InlineLabel WM-F WLYF'})
#     print('designation is: ', designation.get_text())
#     print('address is: ', address.get_text())
    address_label = address.get_text()
    title = designation.get_text()
    address_label_contents = address_label.split('|')
    location_more = address_label_contents[0].strip()
    if location_more.count(',')>1:
        location_trim = location_more.rsplit(',',1)
        location = location_trim[0]
    else:
        location = location_more
    location = re.sub('[^a-zA-Z0-9-]+','-',location)
    title = re.sub('[^a-zA-Z0-9-]','-',title)
    job_id = address_label_contents[1].strip()
#     location.replace(',','-')
#     print(location, job_id)
    if len(address_label_contents)==2:
        url = base_url+title+'_'+address_label_contents[0].strip()
    else:
        url = base_url+location+'/'+title+'_'+job_id
    print(url)
#     print(type(url))
    
browser.close()
            
# working for retreiving all the job names
# job_descrp = bs_data.find_all('div',attrs={'class':'gwt-Label WOTO WISO'})

# for job in job_descrp:
#     print(job.get_text())

# # working for retrieving all the locations
# label = bs_data.find_all('span', attrs ={'class':'gwt-InlineLabel WM-F WLYF'})

# for lblname in label:
#     print(lblname.get_text())
    
    
# div_span_text = bs_data.find_all('li',attrs={'class':'WIYF WK3N WE5 WP-F'})
# for dvsp in div_span_text:
#     print(dvsp.get_text())
# code_blocks = []

# code_blocks.append(job_names)

# print(code_blocks)
# Out:
# lastCount and lenOfPage matched:  10474
# https://statestreet.wd1.myworkdayjobs.com/en-US/Global/job/Kansas-City-Missouri/Fall-2019-Financial-Reporting-Graduate-Internship_R-608399
# https://statestreet.wd1.myworkdayjobs.com/en-US/Global/job/Kansas-City-Missouri/Fall-2019-Financial-Services-Undergraduate-Internship_R-608398
# https://statestreet.wd1.myworkdayjobs.com/en-US/Global/job/Boston-Massachusetts/Central-Assurance-Manager---North-America--VP_R-600641
# https://statestreet.wd1.myworkdayjobs.com/en-US/Global/job/Burlington-Massachusetts/Senior-Financial-Analyst--Charles-River-Development_R-606838
# https://statestreet.wd1.myworkdayjobs.com/en-US/Global/job/Burlington-Massachusetts/Senior-Financial-Analyst--Charles-River-Development_R-606845
# https://statestreet.wd1.myworkdayjobs.com/en-US/Global/job/Burlington-Massachusetts/Finance-Manager--Charles-River-Development_R-606839
# https://statestreet.wd1.myworkdayjobs.com/en-US/Global/job/Gdansk-Poland/Business-Production-Support-Specialist_R-606661
# https://statestreet.wd1.myworkdayjobs.com/en-US/Global/job/Boston-Massachusetts/Platform-Product-Strategist--Vice-President--Global-Exchange-CRD_R-608389
# https://statestreet.wd1.myworkdayjobs.com/en-US/Global/job/Dublin-2-Ireland/IFDS-Transfer-Agency--Client-Relationsip-Manager---Senior-Associate_R-599466
# https://statestreet.wd1.myworkdayjobs.com/en-US/Global/job/Bangalore-India/Oracle-Golden-Gate-DBA_R-604366
# https://statestreet.wd1.myworkdayjobs.com/en-US/Global/job/Dayton-Nevada/Senior-Consultant---C---Java--Middleware--RDBMS---Charles-River-Development_R-607251
# https://statestreet.wd1.myworkdayjobs.com/en-US/Global/job/Hyderabad-India/Fund-Accounting-Associate2_R-607837
# https://statestreet.wd1.myworkdayjobs.com/en-US/Global/job/Boston-Massachusetts/Vice-President--Global-Human-Resources--GHR--Technology_R-603828
# https://statestreet.wd1.myworkdayjobs.com/en-US/Global/job/Hyderabad-India/Fund-Accounting-Associate-2_R-607258
# https://statestreet.wd1.myworkdayjobs.com/en-US/Global/job/Bangalore-India/Transition-Manager_R-608378
# https://statestreet.wd1.myworkdayjobs.com/en-US/Global/job/Hyderabad-India/Fund-Accounting-Associate-2_R-606509
# https://statestreet.wd1.myworkdayjobs.com/en-US/Global/job/Krakow-Poland/Financial-Reporting-Team-Leader--Senior-Associate_R-606216
# https://statestreet.wd1.myworkdayjobs.com/en-US/Global/job/Burlington-Massachusetts/Principal-Java-Developer_R-606946
